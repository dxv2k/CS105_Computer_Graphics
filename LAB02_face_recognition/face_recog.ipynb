# %% [markdown]
# # Import libraries

# %%
from PIL import Image
import face_recognition
from IPython.display import display
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # Face Recognition

# %%
img = mpimg.imread('./img.jpg')
plt.imshow(img)

# %%
# Load the jpg file into a numpy array
image = face_recognition.load_image_file("img.jpg")
face_locations = face_recognition.face_locations(image, number_of_times_to_upsample=0, model="cnn")

i = 0
for face_location in face_locations:

    # Print the location of each face in this image
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # You can access the actual face itself like this:
    face_image = image[top:bottom, left:right]
    pil_image = Image.fromarray(face_image)
    display(pil_image)
# Out:
# A face is located at pixel location Top: 98, Left: 108, Bottom: 262, Right: 272
# <PIL.Image.Image image mode=RGB size=164x164 at 0x1C7981898E0>
# A face is located at pixel location Top: 406, Left: 190, Bottom: 520, Right: 304
# <PIL.Image.Image image mode=RGB size=114x114 at 0x1C799532490>

# %% [markdown]
# # Facial landmark

# %%
from PIL import Image, ImageDraw
import face_recognition

# Load the jpg file into a numpy array
image = face_recognition.load_image_file("people.jpg")

# Find all facial features in all the faces in the image
face_landmarks_list = face_recognition.face_landmarks(image)

print("I found {} face(s) in this photograph.".format(len(face_landmarks_list)))

# Create a PIL imagedraw object so we can draw on the picture
pil_image = Image.fromarray(image)
d = ImageDraw.Draw(pil_image)

for face_landmarks in face_landmarks_list:

    # Print the location of each facial feature in this image
    for facial_feature in face_landmarks.keys():
        print("The {} in this face has the following points: {}".format(facial_feature, face_landmarks[facial_feature]))

    # Let's trace out each facial feature in the image with a line!
    for facial_feature in face_landmarks.keys():
        d.line(face_landmarks[facial_feature], width=5)
# Out:
# I found 12 face(s) in this photograph.
# The chin in this face has the following points: [(868, 161), (868, 169), (868, 177), (869, 185), (871, 193), (874, 200), (879, 206), (885, 212), (892, 214), (900, 214), (908, 210), (915, 205), (920, 199), (924, 191), (926, 184), (928, 176), (930, 168)]
# The left_eyebrow in this face has the following points: [(876, 157), (880, 155), (885, 154), (890, 156), (895, 158)]
# The right_eyebrow in this face has the following points: [(903, 159), (908, 158), (913, 158), (918, 160), (922, 163)]
# The nose_bridge in this face has the following points: [(898, 166), (897, 171), (896, 176), (895, 181)]
# The nose_tip in this face has the following points: [(891, 185), (893, 186), (895, 187), (898, 187), (900, 186)]
# The left_eye in this face has the following points: [(881, 165), (884, 164), (888, 165), (891, 167), (887, 168), (884, 167)]
# The right_eye in this face has the following points: [(905, 169), (908, 167), (911, 168), (915, 169), (911, 171), (908, 170)]
# The top_lip in this face has the following points: [(885, 195), (889, 193), (892, 192), (894, 193), (897, 193), (900, 194), (903, 197), (901, 197), (896, 196), (894, 196), (892, 195), (887, 195)]
# The bottom_lip in this face has the following points: [(903, 197), (899, 200), (896, 201), (893, 201), (891, 201), (888, 199), (885, 195), (887, 195), (891, 197), (894, 197), (896, 197), (901, 197)]
# The chin in this face has the following points: [(757, 36), (758, 41), (759, 47), (760, 52), (762, 58), (765, 62), (769, 66), (774, 69), (780, 70), (785, 69), (790, 66), (794, 62), (797, 56), (798, 51), (799, 45), (800, 40), (801, 34)]
# The left_eyebrow in this face has the following points: [(760, 32), (763, 28), (766, 27), (771, 27), (775, 28)]
# The right_eyebrow in this face has the following points: [(781, 28), (785, 27), (790, 26), (794, 27), (797, 30)]
# The nose_bridge in this face has the following points: [(778, 32), (778, 36), (778, 39), (778, 43)]
# The nose_tip in this face has the following points: [(775, 47), (777, 47), (779, 48), (781, 47), (782, 46)]
# The left_eye in this face has the following points: [(765, 35), (767, 33), (770, 33), (773, 34), (770, 35), (767, 35)]
# The right_eye in this face has the following points: [(784, 34), (786, 32), (789, 32), (792, 34), (789, 34), (786, 34)]
# The top_lip in this face has the following points: [(772, 55), (775, 53), (777, 52), (779, 52), (781, 52), (784, 53), (787, 55), (785, 54), (781, 54), (779, 54), (777, 54), (774, 55)]
# The bottom_lip in this face has the following points: [(787, 55), (784, 56), (781, 57), (779, 57), (777, 57), (775, 57), (772, 55), (774, 55), (777, 55), (779, 55), (781, 54), (785, 54)]
# The chin in this face has the following points: [(865, 54), (865, 59), (865, 64), (866, 69), (867, 74), (870, 79), (873, 82), (877, 85), (883, 85), (888, 85), (892, 83), (896, 80), (898, 76), (900, 72), (901, 67), (902, 63), (902, 58)]
# The left_eyebrow in this face has the following points: [(869, 51), (872, 49), (875, 48), (879, 48), (882, 50)]
# The right_eyebrow in this face has the following points: [(888, 51), (891, 50), (894, 50), (897, 51), (899, 53)]
# The nose_bridge in this face has the following points: [(884, 54), (884, 57), (884, 59), (883, 62)]
# The nose_tip in this face has the following points: [(880, 65), (881, 66), (883, 66), (885, 66), (887, 66)]
# The left_eye in this face has the following points: [(873, 55), (875, 55), (877, 55), (879, 56), (877, 56), (875, 56)]
# The right_eye in this face has the following points: [(889, 57), (891, 56), (894, 56), (896, 57), (894, 58), (891, 58)]
# The top_lip in this face has the following points: [(876, 72), (879, 70), (881, 69), (883, 70), (885, 70), (888, 71), (890, 74), (889, 74), (885, 72), (883, 72), (881, 72), (877, 72)]
# The bottom_lip in this face has the following points: [(890, 74), (888, 75), (885, 76), (883, 75), (881, 75), (878, 74), (876, 72), (877, 72), (881, 73), (883, 73), (885, 73), (889, 74)]
# The chin in this face has the following points: [(624, 209), (625, 218), (627, 226), (629, 234), (634, 242), (640, 249), (647, 255), (654, 259), (663, 260), (670, 258), (676, 253), (680, 246), (683, 238), (686, 230), (688, 222), (689, 214), (690, 205)]
# The left_eyebrow in this face has the following points: [(632, 203), (637, 200), (642, 199), (648, 200), (653, 201)]
# The right_eyebrow in this face has the following points: [(665, 201), (670, 198), (675, 197), (680, 197), (685, 200)]
# The nose_bridge in this face has the following points: [(659, 208), (660, 214), (660, 219), (661, 225)]
# The nose_tip in this face has the following points: [(655, 230), (658, 231), (661, 231), (664, 230), (666, 229)]
# The left_eye in this face has the following points: [(639, 210), (643, 209), (647, 208), (650, 210), (647, 212), (643, 212)]
# The right_eye in this face has the following points: [(668, 209), (671, 207), (675, 207), (679, 208), (676, 210), (672, 210)]
# The top_lip in this face has the following points: [(652, 241), (656, 238), (659, 237), (662, 237), (664, 236), (667, 237), (671, 240), (669, 240), (664, 239), (662, 240), (659, 240), (654, 241)]
# The bottom_lip in this face has the following points: [(671, 240), (668, 243), (665, 245), (662, 246), (660, 246), (656, 244), (652, 241), (654, 241), (659, 241), (662, 242), (664, 241), (669, 240)]
# The chin in this face has the following points: [(800, 59), (800, 64), (800, 70), (801, 76), (803, 81), (807, 85), (813, 87), (819, 89), (825, 90), (832, 89), (838, 88), (843, 86), (847, 82), (850, 77), (851, 72), (852, 66), (853, 60)]
# The left_eyebrow in this face has the following points: [(805, 50), (808, 45), (813, 43), (818, 43), (824, 44)]
# The right_eyebrow in this face has the following points: [(827, 44), (833, 43), (838, 43), (844, 46), (847, 50)]
# The nose_bridge in this face has the following points: [(825, 49), (825, 51), (825, 54), (825, 56)]
# The nose_tip in this face has the following points: [(820, 63), (822, 63), (825, 64), (827, 64), (829, 64)]
# The left_eye in this face has the following points: [(810, 52), (813, 50), (816, 50), (819, 51), (816, 52), (813, 52)]
# The right_eye in this face has the following points: [(832, 52), (835, 50), (838, 51), (841, 53), (838, 53), (835, 53)]
# The top_lip in this face has the following points: [(816, 73), (819, 70), (822, 68), (824, 69), (827, 69), (830, 71), (834, 74), (832, 74), (827, 71), (824, 71), (822, 71), (817, 73)]
# The bottom_lip in this face has the following points: [(834, 74), (830, 75), (827, 74), (824, 74), (822, 74), (819, 74), (816, 73), (817, 73), (822, 71), (824, 71), (827, 71), (832, 74)]
# The chin in this face has the following points: [(665, 65), (665, 73), (667, 81), (668, 89), (671, 97), (677, 103), (683, 108), (691, 111), (699, 112), (707, 110), (714, 106), (720, 101), (725, 94), (727, 86), (728, 78), (728, 70), (728, 62)]
# The left_eyebrow in this face has the following points: [(670, 60), (673, 55), (678, 53), (684, 53), (690, 55)]
# The right_eyebrow in this face has the following points: [(698, 55), (704, 53), (711, 52), (717, 54), (721, 58)]
# The nose_bridge in this face has the following points: [(694, 62), (694, 67), (694, 71), (695, 76)]
# The nose_tip in this face has the following points: [(690, 82), (693, 83), (695, 83), (698, 82), (701, 81)]
# The left_eye in this face has the following points: [(676, 65), (679, 63), (683, 63), (687, 65), (683, 66), (680, 66)]
# The right_eye in this face has the following points: [(702, 64), (706, 62), (710, 62), (714, 63), (710, 64), (706, 65)]
# The top_lip in this face has the following points: [(687, 94), (690, 90), (693, 88), (696, 88), (699, 87), (703, 89), (707, 93), (704, 92), (699, 91), (696, 91), (693, 91), (689, 94)]
# The bottom_lip in this face has the following points: [(707, 93), (703, 96), (700, 98), (696, 98), (693, 98), (690, 97), (687, 94), (689, 94), (693, 93), (696, 93), (699, 92), (704, 92)]
# The chin in this face has the following points: [(89, 45), (90, 50), (91, 54), (93, 59), (95, 64), (99, 67), (104, 69), (109, 71), (114, 72), (119, 70), (123, 67), (126, 64), (129, 60), (130, 56), (130, 51), (130, 46), (130, 40)]
# The left_eyebrow in this face has the following points: [(94, 41), (96, 39), (99, 39), (103, 39), (106, 40)]
# The right_eyebrow in this face has the following points: [(112, 39), (115, 37), (118, 37), (122, 37), (124, 38)]
# The nose_bridge in this face has the following points: [(109, 44), (109, 46), (110, 49), (110, 52)]
# The nose_tip in this face has the following points: [(108, 55), (109, 56), (111, 56), (112, 55), (114, 54)]
# The left_eye in this face has the following points: [(98, 46), (100, 45), (103, 45), (105, 45), (103, 47), (100, 47)]
# The right_eye in this face has the following points: [(114, 45), (116, 43), (118, 43), (121, 44), (119, 45), (116, 45)]
# The top_lip in this face has the following points: [(107, 62), (108, 61), (110, 59), (112, 60), (113, 59), (115, 59), (118, 60), (117, 60), (113, 61), (112, 61), (111, 61), (108, 62)]
# The bottom_lip in this face has the following points: [(118, 60), (116, 62), (114, 63), (113, 63), (111, 63), (109, 63), (107, 62), (108, 62), (111, 61), (112, 61), (114, 61), (117, 60)]
# The chin in this face has the following points: [(303, 39), (303, 45), (304, 50), (305, 55), (307, 61), (310, 65), (315, 68), (321, 69), (328, 69), (336, 69), (343, 68), (349, 65), (353, 61), (355, 56), (356, 50), (356, 44), (357, 38)]
# The left_eyebrow in this face has the following points: [(309, 27), (311, 23), (315, 20), (320, 19), (325, 20)]
# The right_eyebrow in this face has the following points: [(330, 19), (335, 18), (341, 19), (345, 22), (348, 26)]
# The nose_bridge in this face has the following points: [(327, 25), (327, 28), (327, 31), (327, 35)]
# The nose_tip in this face has the following points: [(323, 41), (325, 42), (327, 42), (330, 41), (332, 41)]
# The left_eye in this face has the following points: [(313, 30), (315, 27), (318, 27), (321, 28), (318, 29), (316, 29)]
# The right_eye in this face has the following points: [(334, 28), (337, 26), (340, 26), (343, 29), (340, 29), (337, 28)]
# The top_lip in this face has the following points: [(320, 52), (322, 48), (325, 46), (327, 47), (330, 46), (333, 48), (336, 52), (335, 51), (330, 49), (328, 49), (325, 49), (321, 52)]
# The bottom_lip in this face has the following points: [(336, 52), (333, 53), (330, 53), (327, 54), (325, 53), (322, 53), (320, 52), (321, 52), (325, 51), (327, 51), (330, 51), (335, 51)]
# The chin in this face has the following points: [(678, 266), (678, 276), (679, 286), (681, 295), (684, 305), (688, 314), (694, 321), (701, 327), (710, 329), (720, 328), (729, 323), (738, 316), (745, 308), (749, 298), (752, 288), (753, 278), (754, 267)]
# The left_eyebrow in this face has the following points: [(685, 259), (689, 256), (694, 255), (700, 256), (705, 258)]
# The right_eyebrow in this face has the following points: [(715, 259), (721, 256), (728, 256), (735, 258), (740, 261)]
# The nose_bridge in this face has the following points: [(709, 266), (708, 272), (707, 277), (706, 283)]
# The nose_tip in this face has the following points: [(703, 290), (705, 291), (708, 292), (711, 291), (713, 290)]
# The left_eye in this face has the following points: [(690, 267), (694, 265), (698, 265), (702, 268), (698, 270), (693, 270)]
# The right_eye in this face has the following points: [(719, 269), (723, 266), (727, 267), (731, 269), (728, 271), (723, 271)]
# The top_lip in this face has the following points: [(701, 306), (703, 301), (706, 299), (708, 300), (711, 300), (715, 302), (718, 307), (716, 307), (711, 304), (708, 303), (706, 303), (703, 306)]
# The bottom_lip in this face has the following points: [(718, 307), (715, 311), (711, 312), (708, 312), (706, 311), (703, 310), (701, 306), (703, 306), (706, 306), (708, 306), (710, 306), (716, 307)]
# The chin in this face has the following points: [(197, 43), (198, 48), (200, 53), (201, 58), (203, 63), (205, 68), (209, 71), (214, 73), (219, 73), (225, 73), (229, 71), (234, 68), (236, 64), (237, 59), (238, 54), (238, 49), (238, 44)]
# The left_eyebrow in this face has the following points: [(201, 38), (204, 36), (207, 35), (211, 35), (214, 36)]
# The right_eyebrow in this face has the following points: [(222, 35), (225, 33), (229, 32), (232, 33), (235, 36)]
# The nose_bridge in this face has the following points: [(218, 40), (218, 43), (218, 47), (218, 50)]
# The nose_tip in this face has the following points: [(214, 54), (216, 54), (218, 55), (220, 54), (221, 54)]
# The left_eye in this face has the following points: [(204, 43), (207, 41), (209, 41), (212, 42), (209, 43), (207, 43)]
# The right_eye in this face has the following points: [(224, 42), (226, 40), (229, 40), (231, 42), (229, 43), (226, 43)]
# The top_lip in this face has the following points: [(211, 62), (214, 60), (216, 59), (218, 59), (220, 59), (222, 60), (225, 62), (224, 61), (220, 61), (218, 61), (216, 61), (212, 62)]
# The bottom_lip in this face has the following points: [(225, 62), (222, 63), (220, 63), (218, 63), (216, 63), (214, 63), (211, 62), (212, 62), (216, 60), (218, 60), (220, 60), (224, 61)]
# The chin in this face has the following points: [(580, 12), (579, 17), (578, 22), (578, 27), (579, 32), (581, 37), (584, 41), (588, 44), (592, 46), (598, 45), (603, 44), (607, 41), (611, 37), (613, 33), (615, 28), (616, 23), (618, 18)]
# The left_eyebrow in this face has the following points: [(583, 11), (585, 9), (589, 8), (593, 9), (596, 11)]
# The right_eyebrow in this face has the following points: [(601, 12), (605, 12), (609, 12), (613, 14), (615, 17)]
# The nose_bridge in this face has the following points: [(598, 16), (597, 19), (597, 22), (596, 25)]
# The nose_tip in this face has the following points: [(592, 28), (594, 29), (595, 29), (597, 29), (599, 29)]
# The left_eye in this face has the following points: [(587, 16), (589, 15), (591, 16), (593, 17), (591, 17), (589, 17)]
# The right_eye in this face has the following points: [(602, 18), (605, 18), (608, 18), (610, 19), (607, 20), (605, 20)]
# The top_lip in this face has the following points: [(588, 33), (591, 33), (593, 33), (595, 34), (597, 34), (599, 35), (602, 36), (600, 36), (596, 35), (595, 35), (593, 35), (590, 34)]
# The bottom_lip in this face has the following points: [(602, 36), (598, 36), (596, 36), (594, 36), (592, 35), (591, 35), (588, 33), (590, 34), (593, 33), (594, 34), (596, 34), (600, 36)]
# The chin in this face has the following points: [(160, 243), (161, 253), (164, 263), (166, 272), (170, 280), (175, 288), (181, 294), (188, 300), (196, 301), (204, 299), (212, 294), (219, 288), (226, 280), (231, 271), (234, 261), (235, 250), (236, 239)]
# The left_eyebrow in this face has the following points: [(164, 239), (168, 235), (174, 234), (181, 234), (187, 236)]
# The right_eyebrow in this face has the following points: [(196, 235), (204, 233), (211, 233), (219, 235), (225, 238)]
# The nose_bridge in this face has the following points: [(192, 243), (192, 250), (191, 256), (191, 263)]
# The nose_tip in this face has the following points: [(185, 268), (189, 269), (192, 270), (196, 269), (200, 268)]
# The left_eye in this face has the following points: [(171, 244), (175, 241), (180, 241), (184, 245), (180, 246), (175, 246)]
# The right_eye in this face has the following points: [(203, 245), (206, 241), (212, 241), (217, 243), (212, 245), (207, 245)]
# The top_lip in this face has the following points: [(183, 280), (186, 277), (191, 276), (194, 277), (197, 276), (203, 277), (208, 279), (206, 280), (197, 279), (194, 279), (191, 279), (185, 280)]
# The bottom_lip in this face has the following points: [(208, 279), (203, 285), (198, 288), (194, 289), (191, 289), (187, 286), (183, 280), (185, 280), (191, 283), (194, 284), (197, 284), (206, 280)]

# %%
display(pil_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1008x435 at 0x1C797FBD700>
